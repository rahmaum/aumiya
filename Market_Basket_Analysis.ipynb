# %% [markdown]
# # Overview
#
# The instruction is to practice market basket analysis (association rules).
#
# The rules are as below:
# * Support minimum of 0.002
# * Confidence minimum of 0.05
# * Lift a minimum of 3

# %%
#Packages
# !pip install apyori  ## Installing apriori library
import numpy as np # linear algebra
import pandas as pd # Data pre-processing
import seaborn as sns # Required for plotting
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5973 sha256=b5b126f3c5d37ee439d79c70d6acbe9e086719f3ab57ac8b329795eec1969c32
#   Stored in directory: /root/.cache/pip/wheels/1b/02/6c/a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %% [markdown]
# # import dataset

# %%
# import dataset from spreadsheet
sheet_url = 'https://drive.google.com/file/d/1vfmsAn7vWiHF-rVoFsmu0XINeuWsvxkB/view?usp=sharing' 
#use this trick to get the id of the file
sheet = 'https://drive.google.com/uc?id=' + sheet_url.split('/')[-2] 

#add sep=';' parameter to pandas read_csv function in order to tell the function, to use semicolon (;) as separator
df = pd.read_csv (sheet, sep=',') 
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
df['Member_number'] = df['Member_number'].apply(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  object
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: object(3)
# memory usage: 908.7+ KB

# %% [markdown]
# # Data Pre Processing

# %%
member= df[['Member_number', 'itemDescription']].sort_values(by = 'Member_number', ascending = False) ## Selecting only required variables for modelling
member['itemDescription'] = member['itemDescription'].str.strip() # Removing white spaces if any
member
# Out:
#       Member_number        itemDescription
# 3578           5000                   soda
# 34885          5000    semi-finished bread
# 11728          5000  fruit/vegetable juice
# 9340           5000           bottled beer
# 19727          5000        root vegetables
# ...             ...                    ...
# 13331          1000             whole milk
# 17778          1000     pickled vegetables
# 6388           1000                sausage
# 20992          1000    semi-finished bread
# 8395           1000             whole milk
#
# [38765 rows x 2 columns]

# %%
trx = [a[1]['itemDescription'].tolist() for a in list(member.groupby(['Member_number']))] ## Combing all the items in list format for each cutomer
trx
# Out:
# [['misc. beverages',
#   'sausage',
#   'soda',
#   'yogurt',
#   'salty snack',
#   'pastry',
#   'canned beer',
#   'hygiene articles',
#   'whole milk',
#   'pickled vegetables',
#   'sausage',
#   'semi-finished bread',
#   'whole milk'],
#  ['beef',
#   'sausage',
#   'frankfurter',
#   'soda',
#   'whipped/sour cream',
#   'frankfurter',
#   'rolls/buns',
#   'soda',
#   'white bread',
#   'whole milk',
#   'whole milk',
#   'curd'],
#  ['specialty chocolate',
#   'butter',
#   'whole milk',
#   'butter milk',
#   'tropical fruit',
#   'sugar',
#   'other vegetables',
#   'frozen vegetables'],
#  ['dental care',
#   'rolls/buns',
#   'rolls/buns',
#   'frozen meals',
#   'rolls/buns',
#   'sausage',
#   'detergent',
#   'root vegetables'],
#  ['frozen fish',
#   'shopping bags',
#   'hygiene articles',
#   'rolls/buns',
#   'whole milk',
#   'canned beer',
#   'root vegetables',
#   'tropical fruit',
#   'whole milk',
#   'chocolate',
#   'other vegetables',
#   'red/blush wine',
#   'pastry',
#   'rolls/buns',
#   'packaged fruit/vegetables',
#   'dish cleaner',
#   'pip fruit',
#   'other vegetables',
#   'chocolate',
#   'cling film/bags',
#   'whole milk'],
#  ['rolls/buns', 'rolls/buns', 'margarine', 'whipped/sour cream'],
#  ['bottled water',
#   'frankfurter',
#   'bottled beer',
#   'whole milk',
#   'frankfurter',
#   'rice',
#   'chicken',
#   'softener',
#   'skin care',
#   'shopping bags',
#   'whole milk',
#   'chocolate',
#   'flour',
#   'rolls/buns',
#   'rolls/buns'],
#  ['hamburger meat',
#   'liver loaf',
#   'tropical fruit',
#   'root vegetables',
#   'photo/film',
#   'white wine',
#   'yogurt',
#   'dessert',
#   'domestic eggs',
#   'soda',
#   'yogurt',
#   'liquor (appetizer)'],
#  ['canned fish',
#   'newspapers',
#   'tropical fruit',
#   'cocoa drinks',
#   'pastry',
#   'yogurt',
#   'ketchup',
#   'herbs',
#   'yogurt'],
#  ['rolls/buns',
#   'kitchen towels',
#   'frankfurter',
#   'coffee',
#   'candles',
#   'bottled water',
#   'sliced cheese',
#   'pip fruit',
#   'bottled water',
#   'pip fruit',
#   'UHT-milk',
#   'specialty bar'],
#  ['candles',
#   'grapes',
#   'frankfurter',
#   'whole milk',
#   'pastry',
#   'rolls/buns',
#   'bottled water',
#   'yogurt',
#   'curd cheese',
#   'citrus fruit',
#   'other vegetables',
#   'candy',
#   'herbs'],
#  ['tropical fruit',
#   'root vegetables',
#   'whole milk',
#   'frozen vegetables',
#   'shopping bags',
#   'brown bread',
#   'rolls/buns',
#   'onions',
#   'yogurt',
#   'frankfurter',
#   'processed cheese'],
#  ['whole milk',
#   'white bread',
#   'hard cheese',
#   'napkins',
#   'whole milk',
#   'other vegetables',
#   'domestic eggs',
#   'candy',
#   'bottled water',
#   'mayonnaise',
#   'meat',
#   'roll products',
#   'root vegetables',
#   'mustard',
#   'tropical fruit',
#   'frozen meals',
#   'whipped/sour cream',
#   'mustard',
#   'frozen vegetables'],
#  ['sausage',
#   'whole milk',
#   'canned beer',
#   'butter milk',
#   'yogurt',
#   'cookware',
#   'bottled beer',
#   'whole milk',
#   'hamburger meat',
#   'rolls/buns'],
#  ['rolls/buns',
#   'chocolate',
#   'whole milk',
#   'beef',
#   'citrus fruit',
#   'fruit/vegetable juice',
#   'salty snack'],
#  ['pip fruit',
#   'rolls/buns',
#   'pip fruit',
#   'chicken',
#   'frankfurter',
#   'oil',
#   'bottled beer',
#   'soft cheese',
#   'mayonnaise',
#   'UHT-milk',
#   'red/blush wine'],
#  ['dessert',
#   'beef',
#   'yogurt',
#   'pet care',
#   'rolls/buns',
#   'other vegetables',
#   'shopping bags',
#   'brown bread',
#   'other vegetables',
#   'soda',
#   'root vegetables'],
#  ['long life bakery product',
#   'root vegetables',
#   'butter milk',
#   'domestic eggs',
#   'curd',
#   'berries',
#   'cake bar',
#   'beverages'],
#  ['red/blush wine', 'hamburger meat'],
#  ['butter',
#   'yogurt',
#   'rolls/buns',
#   'spices',
#   'frozen fish',
#   'frozen meals',
#   'canned beer',
#   'newspapers',
#   'shopping bags',
#   'canned beer'],
#  ['yogurt',
#   'sliced cheese',
#   'curd',
#   'baking powder',
#   'rolls/buns',
#   'liquor',
#   'tropical fruit',
#   'butter'],
#  ['napkins',
#   'sausage',
#   'beef',
#   'whole milk',
#   'fruit/vegetable juice',
#   'whipped/sour cream'],
#  ['whipped/sour cream',
#   'yogurt',
#   'packaged fruit/vegetables',
#   'domestic eggs',
#   'chicken',
#   'rolls/buns',
#   'male cosmetics',
#   'berries',
#   'specialty bar',
#   'sausage',
#   'bottled beer',
#   'soda',
#   'curd',
#   'whipped/sour cream',
#   'white bread',
#   'frozen meals',
#   'root vegetables'],
#  ['other vegetables', 'tropical fruit', 'root vegetables', 'fish'],
#  ['ham', 'canned beer', 'shopping bags', 'UHT-milk', 'coffee', 'cream cheese'],
#  ['canned beer',
#   'citrus fruit',
#   'sausage',
#   'candy',
#   'butter',
#   'root vegetables',
#   'dessert',
#   'long life bakery product',
#   'rolls/buns',
#   'yogurt',
#   'whipped/sour cream',
#   'fruit/vegetable juice',
#   'pickled vegetables',
#   'root vegetables',
#   'salty snack',
#   'dental care',
#   'root vegetables'],
#  ['whole milk',
#   'salt',
#   'bottled water',
#   'rolls/buns',
#   'rolls/buns',
#   'softener',
#   'pork',
#   'red/blush wine',
#   'hamburger meat'],
#  ['butter',
#   'flower (seeds)',
#   'specialty chocolate',
#   'rolls/buns',
#   'root vegetables',
#   'bottled water',
#   'soda',
#   'onions',
#   'rolls/buns',
#   'baking powder',
#   'canned beer',
#   'sugar',
#   'onions'],
#  ['dessert', 'ham'],
#  ['cream cheese',
#   'pot plants',
#   'beverages',
#   'other vegetables',
#   'berries',
#   'ice cream',
#   'other vegetables'],
#  ['pastry',
#   'yogurt',
#   'soda',
#   'white bread',
#   'newspapers',
#   'cream cheese',
#   'other vegetables',
#   'whipped/sour cream',
#   'whole milk',
#   'white bread',
#   'root vegetables',
#   'shopping bags',
#   'whipped/sour cream',
#   'butter',
#   'ice cream',
#   'berries'],
#  ['pastry',
#   'tropical fruit',
#   'dessert',
#   'rolls/buns',
#   'soda',
#   'sausage',
#   'frankfurter',
#   'rolls/buns',
#   'fruit/vegetable juice',
#   'waffles',
#   'chicken',
#   'snack products'],
#  ['frozen meals',
#   'tropical fruit',
#   'cling film/bags',
#   'cat food',
#   'domestic eggs',
#   'bottled water',
#   'pip fruit',
#   'newspapers',
#   'yogurt'],
#  ['salt',
#   'yogurt',
#   'frozen vegetables',
#   'sausage',
#   'pip fruit',
#   'rolls/buns',
#   'whole milk',
#   'white wine',
#   'frozen vegetables',
#   'white bread',
#   'yogurt',
#   'newspapers',
#   'whole milk',
#   'whole milk'],
#  ['vinegar', 'fruit/vegetable juice'],
#  ['yogurt',
#   'citrus fruit',
#   'rolls/buns',
#   'canned beer',
#   'shopping bags',
#   'white bread',
#   'tropical fruit',
#   'chewing gum',
#   'frankfurter',
#   'cake bar'],
#  ['specialty chocolate',
#   'pip fruit',
#   'cake bar',
#   'napkins',
#   'Instant food products',
#   'butter',
#   'herbs',
#   'whipped/sour cream',
#   'whole milk',
#   'whipped/sour cream',
#   'butter',
#   'pork',
#   'pip fruit',
#   'sausage',
#   'whole milk',
#   'fruit/vegetable juice',
#   'frozen meals',
#   'other vegetables',
#   'margarine'],
#  ['rolls/buns', 'salty snack'],
#  ['tropical fruit',
#   'packaged fruit/vegetables',
#   'rolls/buns',
#   'white bread',
#   'yogurt',
#   'whole milk',
#   'root vegetables',
#   'rolls/buns',
#   'onions',
#   'pasta',
#   'chicken'],
#  ['tropical fruit',
#   'candy',
#   'frozen vegetables',
#   'brown bread',
#   'chicken',
#   'whole milk',
#   'dessert',
#   'prosecco',
#   'hamburger meat',
#   'yogurt'],
#  ['whole milk',
#   'dessert',
#   'citrus fruit',
#   'other vegetables',
#   'bottled water',
#   'beef'],
#  ['napkins',
#   'citrus fruit',
#   'chocolate marshmallow',
#   'sliced cheese',
#   'whole milk',
#   'whole milk',
#   'rolls/buns',
#   'tropical fruit'],
#  ['tropical fruit', 'curd', 'other vegetables', 'root vegetables'],
#  ['specialty chocolate',
#   'root vegetables',
#   'yogurt',
#   'chicken',
#   'onions',
#   'butter',
#   'yogurt',
#   'Instant food products',
#   'fruit/vegetable juice'],
#  ['pastry', 'whole milk', 'pork', 'bottled water'],
#  ['pip fruit', 'soda', 'soda', 'curd', 'sweet spreads', 'butter'],
#  ['rolls/buns',
#   'rolls/buns',
#   'condensed milk',
#   'soda',
#   'whole milk',
#   'tropical fruit'],
#  ['whole milk',
#   'frankfurter',
#   'margarine',
#   'white bread',
#   'candy',
#   'herbs',
#   'specialty bar',
#   'butter'],
#  ['whipped/sour cream',
#   'dishes',
#   'meat',
#   'UHT-milk',
#   'beverages',
#   'cat food',
#   'other vegetables',
#   'pasta',
#   'house keeping products',
#   'whole milk',
#   'hygiene articles',
#   'yogurt',
#   'waffles',
#   'yogurt'],
#  ['rolls/buns',
#   'soda',
#   'popcorn',
#   'bottled beer',
#   'hamburger meat',
#   'fish',
#   'hamburger meat',
#   'frozen vegetables',
#   'other vegetables',
#   'shopping bags',
#   'red/blush wine',
#   'cream cheese',
#   'coffee',
#   'female sanitary products',
#   'tropical fruit',
#   'pork',
#   'tropical fruit',
#   'dishes',
#   'other vegetables',
#   'shopping bags'],
#  ['soft cheese',
#   'butter',
#   'bottled water',
#   'chewing gum',
#   'beef',
#   'dog food',
#   'whole milk',
#   'pork',
#   'whipped/sour cream',
#   'chicken',
#   'margarine',
#   'soda',
#   'beverages',
#   'shopping bags',
#   'grapes',
#   'shopping bags',
#   'yogurt',
#   'hamburger meat',
#   'yogurt',
#   'yogurt',
#   'coffee',
#   'frankfurter',
#   'butter milk',
#   'root vegetables',
#   'detergent',
#   'soda',
#   'other vegetables'],
#  ['pastry',
#   'frozen vegetables',
#   'other vegetables',
#   'rolls/buns',
#   'whole milk',
#   'soda',
#   'soda',
#   'chicken',
#   'waffles',
#   'sugar',
#   'hamburger meat',
#   'whole milk'],
#  ['fruit/vegetable juice',
#   'citrus fruit',
#   'margarine',
#   'other vegetables',
#   'photo/film',
#   'soda',
#   'oil',
#   'frankfurter',
#   'bottled beer'],
#  ['white wine', 'pork', 'yogurt', 'bottled water', 'newspapers', 'soda'],
#  ['pip fruit',
#   'whole milk',
#   'meat spreads',
#   'ham',
#   'whipped/sour cream',
#   'other vegetables'],
#  ['sliced cheese',
#   'tropical fruit',
#   'pickled vegetables',
#   'soda',
#   'salty snack',
#   'UHT-milk',
#   'domestic eggs',
#   'soda'],
#  ['yogurt',
#   'bottled water',
#   'root vegetables',
#   'sausage',
#   'other vegetables',
#   'chicken',
#   'root vegetables',
#   'other vegetables'],
#  ['spread cheese', 'cling film/bags', 'dessert', 'sausage', 'salty snack'],
#  ['whole milk',
#   'Instant food products',
#   'whipped/sour cream',
#   'fruit/vegetable juice',
#   'chocolate',
#   'tropical fruit',
#   'root vegetables',
#   'soda',
#   'beef',
#   'hard cheese',
#   'beverages',
#   'bottled beer',
#   'dessert',
#   'margarine'],
#  ['white bread',
#   'ketchup',
#   'whipped/sour cream',
#   'sauces',
#   'tropical fruit',
#   'yogurt',
#   'long life bakery product',
#   'shopping bags',
#   'ham',
#   'other vegetables',
#   'frozen fruits',
#   'whole milk',
#   'whole milk',
#   'other vegetables',
#   'butter',
#   'whole milk'],
#  ['whole milk', 'rolls/buns', 'candy', 'citrus fruit'],
#  ['rolls/buns',
#   'cream cheese',
#   'root vegetables',
#   'whole milk',
#   'root vegetables',
#   'long life bakery product',
#   'other vegetables'],
#  ['beef',
#   'rum',
#   'soda',
#   'whole milk',
#   'tropical fruit',
#   'frankfurter',
#   'frozen fish',
#   'red/blush wine',
#   'dessert',
#   'hamburger meat',
#   'long life bakery product',
#   'rolls/buns',
#   'tropical fruit',
#   'tropical fruit'],
#  ['shopping bags',
#   'other vegetables',
#   'whole milk',
#   'oil',
#   'bottled beer',
#   'root vegetables'],
#  ['coffee',
#   'pork',
#   'hamburger meat',
#   'whole milk',
#   'tropical fruit',
#   'rolls/buns',
#   'chocolate',
#   'tropical fruit'],
#  ['yogurt', 'soda', 'pork', 'spread cheese'],
#  ['bottled beer',
#   'sliced cheese',
#   'domestic eggs',
#   'dishes',
#   'fruit/vegetable juice',
#   'pork',
#   'tropical fruit',
#   'rolls/buns',
#   'brown bread',
#   'salt'],
#  ['citrus fruit', 'newspapers', 'red/blush wine', 'cream cheese'],
#  ['yogurt', 'roll products', 'fruit/vegetable juice'],
#  ['canned beer', 'frankfurter', 'other vegetables', 'ham'],
#  ['dishes',
#   'bottled water',
#   'prosecco',
#   'domestic eggs',
#   'finished products',
#   'pip fruit',
#   'brown bread',
#   'yogurt',
#   'pip fruit',
#   'brown bread',
#   'curd',
#   'salt'],
#  ['shopping bags',
#   'semi-finished bread',
#   'ketchup',
#   'instant coffee',
#   'detergent',
#   'oil',
#   'misc. beverages',
#   'fruit/vegetable juice',
#   'flower (seeds)',
#   'candy'],
#  ['frankfurter',
#   'canned fish',
#   'fruit/vegetable juice',
#   'frozen meals',
#   'pip fruit',
#   'UHT-milk',
#   'dishes',
#   'bottled water',
#   'frankfurter',
#   'citrus fruit',
#   'rolls/buns'],
#  ['sausage',
#   'frankfurter',
#   'sausage',
#   'brown bread',
#   'bottled water',
#   'whole milk',
#   'coffee',
#   'bottled water',
#   'butter',
#   'ham',
#   'whole milk',
#   'chicken',
#   'butter'],
#  ['root vegetables',
#   'brown bread',
#   'butter',
#   'rolls/buns',
#   'other vegetables',
#   'soda',
#   'tropical fruit',
#   'rolls/buns',
#   'pastry',
#   'white bread',
#   'pasta',
#   'soda',
#   'canned beer',
#   'artif. sweetener'],
#  ['frankfurter',
#   'white bread',
#   'chicken',
#   'soda',
#   'coffee',
#   'curd',
#   'rolls/buns'],
#  ['rolls/buns',
#   'napkins',
#   'bottled water',
#   'onions',
#   'sweet spreads',
#   'red/blush wine'],
#  ['root vegetables', 'frozen vegetables', 'pet care', 'canned beer', 'soda'],
#  ['specialty bar',
#   'pastry',
#   'other vegetables',
#   'baking powder',
#   'newspapers',
#   'butter milk',
#   'whole milk',
#   'bottled beer',
#   'beverages',
#   'whole milk',
#   'coffee',
#   'tropical fruit',
#   'frankfurter',
#   'yogurt',
#   'tropical fruit',
#   'yogurt'],
#  ['other vegetables',
#   'bottled water',
#   'margarine',
#   'hygiene articles',
#   'beef'],
#  ['specialty chocolate',
#   'pork',
#   'hamburger meat',
#   'sliced cheese',
#   'whole milk',
#   'soda',
#   'bathroom cleaner'],
#  ['other vegetables', 'pip fruit'],
#  ['citrus fruit',
#   'newspapers',
#   'yogurt',
#   'root vegetables',
#   'shopping bags',
#   'soda',
#   'other vegetables'],
#  ['soda',
#   'other vegetables',
#   'rolls/buns',
#   'soda',
#   'canned beer',
#   'whipped/sour cream',
#   'rolls/buns',
#   'curd',
#   'beef',
#   'ice cream',
#   'citrus fruit',
#   'margarine',
#   'butter',
#   'herbs'],
#  ['flower (seeds)',
#   'other vegetables',
#   'jam',
#   'sausage',
#   'cake bar',
#   'pot plants',
#   'white bread',
#   'whole milk',
#   'sausage',
#   'white bread',
#   'whole milk',
#   'beverages',
#   'specialty chocolate',
#   'pip fruit',
#   'herbs',
#   'ham',
#   'chocolate',
#   'coffee',
#   'whole milk',
#   'berries',
#   'soda'],
#  ['domestic eggs',
#   'baking powder',
#   'whole milk',
#   'berries',
#   'hard cheese',
#   'meat',
#   'tropical fruit',
#   'other vegetables',
#   'yogurt'],
#  ['sauces', 'yogurt'],
#  ['pastry',
#   'sausage',
#   'dishes',
#   'detergent',
#   'specialty chocolate',
#   'yogurt',
#   'whisky',
#   'napkins',
#   'yogurt',
#   'whole milk',
#   'ice cream',
#   'beef'],
#  ['root vegetables',
#   'rolls/buns',
#   'photo/film',
#   'other vegetables',
#   'bottled beer',
#   'domestic eggs',
#   'Instant food products',
#   'salty snack',
#   'grapes',
#   'frozen vegetables',
#   'soda',
#   'sausage',
#   'shopping bags',
#   'frankfurter',
#   'specialty bar',
#   'bottled beer',
#   'other vegetables',
#   'bottled water',
#   'newspapers',
#   'yogurt'],
#  ['dessert', 'domestic eggs'],
#  ['other vegetables',
#   'whole milk',
#   'tropical fruit',
#   'detergent',
#   'soda',
#   'newspapers',
#   'whole milk',
#   'root vegetables',
#   'tropical fruit',
#   'whole milk',
#   'hamburger meat',
#   'chocolate marshmallow',
#   'flour',
#   'salty snack',
#   'sausage',
#   'waffles',
#   'sausage',
#   'pasta',
#   'misc. beverages',
#   'brown bread'],
#  ['domestic eggs',
#   'flour',
#   'pork',
#   'bottled water',
#   'shopping bags',
#   'yogurt',
#   'packaged fruit/vegetables',
#   'pickled vegetables'],
#  ['pip fruit', 'fruit/vegetable juice'],
#  ['cake bar',
#   'whole milk',
#   'root vegetables',
#   'curd',
#   'shopping bags',
#   'frankfurter',
#   'whipped/sour cream',
#   'tropical fruit',
#   'hard cheese',
#   'whole milk',
#   'soda',
#   'whole milk',
#   'bottled water',
#   'whipped/sour cream',
#   'shopping bags',
#   'curd',
#   'sausage'],
#  ['cat food',
#   'grapes',
#   'yogurt',
#   'frozen vegetables',
#   'canned beer',
#   'whole milk',
#   'other vegetables',
#   'cat food',
#   'tropical fruit',
#   'specialty chocolate',
#   'citrus fruit',
#   'shopping bags',
#   'rolls/buns',
#   'tropical fruit',
#   'frankfurter',
#   'bottled water',
#   'rolls/buns',
#   'dessert',
#   'canned beer',
#   'napkins',
#   'citrus fruit',
#   'hard cheese',
#   'candy',
#   'root vegetables'],
#  ['root vegetables',
#   'pip fruit',
#   'brown bread',
#   'spread cheese',
#   'pork',
#   'instant coffee'],
#  ['grapes',
#   'yogurt',
#   'butter milk',
#   'whole milk',
#   'hygiene articles',
#   'pasta',
#   'butter',
#   'hamburger meat',
#   'pudding powder',
#   'soda'],
#  ['brown bread',
#   'rolls/buns',
#   'processed cheese',
#   'whipped/sour cream',
#   'sparkling wine',
#   'other vegetables',
#   'whole milk'],
#  ['brown bread',
#   'root vegetables',
#   'candy',
#   'yogurt',
#   'white bread',
#   'frozen vegetables',
#   'detergent',
#   'other vegetables',
#   'white wine',
#   'beverages'],
#  ['chicken',
#   'waffles',
#   'pastry',
#   'hygiene articles',
#   'cream',
#   'ice cream',
#   'tea',
#   'yogurt',
#   'herbs',
#   'candles'],
#  ['yogurt',
#   'rolls/buns',
#   'root vegetables',
#   'herbs',
#   'yogurt',
#   'yogurt',
#   'domestic eggs',
#   'pork',
#   'whole milk',
#   'other vegetables'],
#  ['whole milk',
#   'tropical fruit',
#   'other vegetables',
#   'bottled water',
#   'white bread',
#   'yogurt'],
#  ['chicken',
#   'whole milk',
#   'misc. beverages',
#   'semi-finished bread',
#   'newspapers',
#   'liver loaf',
#   'shopping bags',
#   'rolls/buns',
#   'newspapers',
#   'rolls/buns',
#   'misc. beverages',
#   'pastry',
#   'spread cheese',
#   'shopping bags',
#   'citrus fruit',
#   'specialty fat',
#   'citrus fruit',
#   'rolls/buns',
#   'onions',
#   'beef'],
#  ['shopping bags',
#   'grapes',
#   'pastry',
#   'frozen potato products',
#   'whipped/sour cream',
#   'canned beer',
#   'specialty cheese',
#   'salty snack',
#   'brown bread',
#   'pastry',
#   'oil',
#   'whole milk'],
#  ['frozen vegetables',
#   'chocolate',
#   'citrus fruit',
#   'pip fruit',
#   'sugar',
#   'margarine',
#   'whole milk',
#   'salty snack',
#   'curd',
#   'pip fruit',
#   'margarine',
#   'pastry'],
#  ['margarine',
#   'ham',
#   'liquor',
#   'yogurt',
#   'chocolate',
#   'pastry',
#   'margarine',
#   'dishes',
#   'salty snack',
#   'yogurt',
#   'curd',
#   'butter',
#   'whole milk',
#   'pickled vegetables',
#   'soda',
#   'soda',
#   'baking powder',
#   'bottled water'],
#  ['other vegetables',
#   'bottled water',
#   'beef',
#   'sugar',
#   'flour',
#   'whipped/sour cream',
#   'whole milk',
#   'soda',
#   'UHT-milk',
#   'frozen vegetables',
#   'semi-finished bread'],
#  ['newspapers', 'jam', 'ice cream', 'dish cleaner'],
#  ['whole milk',
#   'newspapers',
#   'baking powder',
#   'yogurt',
#   'pudding powder',
#   'bottled beer',
#   'specialty bar',
#   'pork',
#   'curd',
#   'canned beer',
#   'domestic eggs'],
#  ['misc. beverages',
#   'brown bread',
#   'salty snack',
#   'UHT-milk',
#   'sausage',
#   'dessert',
#   'root vegetables',
#   'root vegetables',
#   'shopping bags',
#   'dog food',
#   'chocolate',
#   'shopping bags',
#   'citrus fruit',
#   'shopping bags',
#   'white bread',
#   'chicken'],
#  ['butter',
#   'other vegetables',
#   'other vegetables',
#   'yogurt',
#   'whipped/sour cream',
#   'yogurt',
#   'root vegetables',
#   'turkey'],
#  ['cream cheese',
#   'other vegetables',
#   'bottled water',
#   'canned vegetables',
#   'chicken',
#   'root vegetables',
#   'rolls/buns',
#   'brown bread',
#   'brown bread',
#   'zwieback',
#   'other vegetables',
#   'butter milk',
#   'napkins',
#   'newspapers',
#   'soda',
#   'hard cheese',
#   'soda',
#   'white bread',
#   'newspapers',
#   'beverages',
#   'liquor',
#   'frankfurter',
#   'rolls/buns',
#   'other vegetables'],
#  ['whipped/sour cream', 'whole milk', 'meat'],
#  ['processed cheese',
#   'berries',
#   'curd',
#   'bottled beer',
#   'hair spray',
#   'house keeping products',
#   'pickled vegetables',
#   'whole milk',
#   'rolls/buns',
#   'canned beer',
#   'butter',
#   'pip fruit',
#   'sliced cheese',
#   'yogurt',
#   'pastry',
#   'condensed milk',
#   'ham',
#   'frozen vegetables'],
#  ['grapes', 'whole milk'],
#  ['soda',
#   'pastry',
#   'sugar',
#   'tropical fruit',
#   'meat',
#   'UHT-milk',
#   'tropical fruit',
#   'brown bread',
#   'citrus fruit',
#   'newspapers',
#   'other vegetables',
#   'rice',
#   'other vegetables',
#   'condensed milk',
#   'white bread',
#   'specialty bar',
#   'chocolate marshmallow'],
#  ['shopping bags', 'coffee'],
#  ['citrus fruit',
#   'dishes',
#   'bottled water',
#   'frozen vegetables',
#   'root vegetables',
#   'chicken'],
#  ['yogurt',
#   'frozen vegetables',
#   'canned vegetables',
#   'rolls/buns',
#   'soda',
#   'rolls/buns',
#   'oil',
#   'pip fruit',
#   'cling film/bags',
#   'whole milk',
#   'pork'],
#  ['bottled beer', 'soda', 'hygiene articles', 'yogurt'],
#  ['margarine',
#   'citrus fruit',
#   'popcorn',
#   'rolls/buns',
#   'margarine',
#   'rolls/buns',
#   'pastry',
#   'condensed milk',
#   'root vegetables',
#   'sausage',
#   'shopping bags'],
#  ['misc. beverages',
#   'whipped/sour cream',
#   'napkins',
#   'long life bakery product',
#   'rolls/buns',
#   'pork',
#   'whole milk',
#   'newspapers',
#   'root vegetables'],
#  ['citrus fruit',
#   'soda',
#   'UHT-milk',
#   'frankfurter',
#   'rolls/buns',
#   'pastry',
#   'other vegetables',
#   'butter',
#   'shopping bags',
#   'soda',
#   'roll products',
#   'margarine'],
#  ['coffee',
#   'domestic eggs',
#   'liquor',
#   'frozen vegetables',
#   'frozen vegetables',
#   'white bread',
#   'meat',
#   'soda',
#   'frankfurter',
#   'specialty bar'],
#  ['baking powder',
#   'flower (seeds)',
#   'yogurt',
#   'grapes',
#   'cream cheese',
#   'white wine',
#   'shopping bags',
#   'brown bread',
#   'frozen meals',
#   'flower (seeds)',
#   'specialty chocolate',
#   'whole milk',
#   'tea'],
#  ['soda',
#   'frankfurter',
#   'bottled water',
#   'root vegetables',
#   'softener',
#   'margarine',
#   'yogurt',
#   'cream cheese',
#   'tropical fruit',
#   'cream cheese',
#   'dessert'],
#  ['other vegetables',
#   'soda',
#   'whole milk',
#   'rolls/buns',
#   'other vegetables',
#   'salty snack',
#   'whole milk',
#   'bottled beer',
#   'shopping bags',
#   'semi-finished bread'],
#  ['shopping bags',
#   'curd',
#   'rolls/buns',
#   'yogurt',
#   'napkins',
#   'domestic eggs',
#   'shopping bags',
#   'pork',
#   'coffee',
#   'whole milk',
#   'sausage',
#   'rice',
#   'pastry'],
#  ['yogurt',
#   'oil',
#   'newspapers',
#   'other vegetables',
#   'pastry',
#   'cream cheese',
#   'brown bread'],
#  ['butter',
#   'butter',
#   'sausage',
#   'soda',
#   'other vegetables',
#   'soda',
#   'dessert',
#   'hard cheese',
#   'whole milk',
#   'shopping bags'],
#  ['flower (seeds)',
#   'tropical fruit',
#   'tropical fruit',
#   'beef',
#   'citrus fruit',
#   'brown bread',
#   'butter milk',
#   'instant coffee',
#   'shopping bags',
#   'root vegetables',
#   'butter milk',
#   'fruit/vegetable juice',
#   'whole milk',
#   'other vegetables',
#   'citrus fruit',
#   'herbs',
#   'tropical fruit',
#   'other vegetables',
#   'rolls/buns'],
#  ['other vegetables',
#   'sugar',
#   'nut snack',
#   'whole milk',
#   'canned beer',
#   'other vegetables'],
#  ['whole milk',
#   'root vegetables',
#   'butter milk',
#   'rolls/buns',
#   'citrus fruit',
#   'napkins'],
#  ['brown bread',
#   'tropical fruit',
#   'tropical fruit',
#   'pork',
#   'misc. beverages',
#   'pickled vegetables',
#   'rolls/buns',
#   'canned beer',
#   'soft cheese'],
#  ['other vegetables',
#   'pip fruit',
#   'other vegetables',
#   'photo/film',
#   'cling film/bags',
#   'curd',
#   'frankfurter',
#   'waffles'],
#  ['yogurt',
#   'whole milk',
#   'tropical fruit',
#   'rolls/buns',
#   'soda',
#   'rolls/buns',
#   'white bread',
#   'cat food',
#   'berries'],
#  ['soups',
#   'newspapers',
#   'other vegetables',
#   'brown bread',
#   'chicken',
#   'rolls/buns',
#   'soda',
#   'napkins'],
#  ['whole milk',
#   'misc. beverages',
#   'pickled vegetables',
#   'soda',
#   'soda',
#   'pork',
#   'spread cheese',
#   'UHT-milk',
#   'soda',
#   'oil',
#   'whole milk',
#   'sugar'],
#  ['fish',
#   'hard cheese',
#   'coffee',
#   'domestic eggs',
#   'white bread',
#   'soda',
#   'meat',
#   'domestic eggs',
#   'whipped/sour cream',
#   'pork',
#   'chicken',
#   'root vegetables',
#   'whole milk',
#   'canned beer',
#   'white bread',
#   'root vegetables'],
#  ['other vegetables',
#   'brown bread',
#   'root vegetables',
#   'tropical fruit',
#   'bottled beer',
#   'soda'],
#  ['candy',
#   'bottled water',
#   'margarine',
#   'shopping bags',
#   'other vegetables',
#   'sliced cheese',
#   'pip fruit',
#   'soda',
#   'yogurt',
#   'bottled beer',
#   'curd',
#   'soft cheese',
#   'frozen vegetables',
#   'whole milk',
#   'root vegetables',
#   'waffles',
#   'pork',
#   'berries',
#   'cereals',
#   'yogurt'],
#  ['specialty chocolate',
#   'canned fish',
#   'soda',
#   'whole milk',
#   'frozen meals',
#   'detergent'],
#  ['other vegetables',
#   'yogurt',
#   'whole milk',
#   'tropical fruit',
#   'white bread',
#   'pork',
#   'yogurt',
#   'soda',
#   'shopping bags',
#   'other vegetables',
#   'soda',
#   'sausage',
#   'sliced cheese',
#   'soda',
#   'root vegetables',
#   'baking powder',
#   'pork',
#   'long life bakery product',
#   'dog food'],
#  ['seasonal products',
#   'yogurt',
#   'yogurt',
#   'soda',
#   'frozen vegetables',
#   'bottled beer',
#   'chicken'],
#  ['rolls/buns',
#   'bottled water',
#   'pip fruit',
#   'canned beer',
#   'fruit/vegetable juice',
#   'long life bakery product',
#   'sugar',
#   'other vegetables',
#   'UHT-milk',
#   'berries'],
#  ['pastry', 'curd', 'pip fruit', 'soft cheese', 'berries'],
#  ['domestic eggs',
#   'soda',
#   'curd cheese',
#   'pork',
#   'frozen meals',
#   'soda',
#   'whole milk',
#   'rolls/buns'],
#  ['ice cream',
#   'canned beer',
#   'frankfurter',
#   'cake bar',
#   'tropical fruit',
#   'bottled beer',
#   'soft cheese',
#   'whole milk',
#   'grapes',
#   'butter',
#   'rolls/buns',
#   'whole milk',
#   'mustard',
#   'chicken',
#   'dish cleaner',
#   'chewing gum',
#   'ready soups'],
#  ['frozen vegetables',
#   'root vegetables',
#   'other vegetables',
#   'whole milk',
#   'sausage',
#   'rolls/buns',
#   'canned beer',
#   'citrus fruit',
#   'female sanitary products'],
#  ['whole milk',
#   'sausage',
#   'frankfurter',
#   'whole milk',
#   'yogurt',
#   'house keeping products',
#   'pet care',
#   'brandy'],
#  ['berries', 'other vegetables'],
#  ['tropical fruit',
#   'napkins',
#   'frozen meals',
#   'curd',
#   'beef',
#   'UHT-milk',
#   'whole milk'],
#  ['butter',
#   'whole milk',
#   'citrus fruit',
#   'bottled water',
#   'rolls/buns',
#   'root vegetables',
#   'rolls/buns',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'cream cheese'],
#  ['light bulbs',
#   'citrus fruit',
#   'soda',
#   'citrus fruit',
#   'frozen vegetables',
#   'domestic eggs'],
#  ['chewing gum',
#   'whole milk',
#   'shopping bags',
#   'yogurt',
#   'mustard',
#   'frozen meals',
#   'pip fruit',
#   'bottled beer',
#   'root vegetables',
#   'beef',
#   'coffee',
#   'butter',
#   'whole milk',
#   'tropical fruit',
#   'domestic eggs'],
#  ['beef',
#   'bottled beer',
#   'whole milk',
#   'newspapers',
#   'other vegetables',
#   'spread cheese',
#   'yogurt'],
#  ['canned beer',
#   'salty snack',
#   'canned beer',
#   'fruit/vegetable juice',
#   'berries',
#   'coffee',
#   'male cosmetics',
#   'misc. beverages',
#   'citrus fruit',
#   'red/blush wine',
#   'white bread',
#   'yogurt'],
#  ['white bread',
#   'bottled water',
#   'bottled water',
#   'sausage',
#   'newspapers',
#   'frozen vegetables',
#   'beef',
#   'citrus fruit',
#   'whole milk'],
#  ['other vegetables',
#   'canned vegetables',
#   'whole milk',
#   'root vegetables',
#   'sliced cheese'],
#  ['house keeping products',
#   'whole milk',
#   'curd',
#   'chocolate',
#   'packaged fruit/vegetables',
#   'beef',
#   'frozen vegetables',
#   'spices',
#   'pork'],
#  ['brown bread', 'root vegetables', 'bottled water', 'tropical fruit'],
#  ['rolls/buns', 'coffee', 'other vegetables', 'domestic eggs'],
#  ['sweet spreads',
#   'UHT-milk',
#   'whole milk',
#   'bottled beer',
#   'herbs',
#   'chocolate',
#   'frankfurter',
#   'frozen vegetables',
#   'long life bakery product'],
#  ['napkins',
#   'waffles',
#   'finished products',
#   'margarine',
#   'soda',
#   'whipped/sour cream',
#   'cake bar',
#   'napkins',
#   'liquor',
#   'other vegetables',
#   'detergent',
#   'rolls/buns',
#   'whole milk',
#   'white bread',
#   'newspapers',
#   'soda',
#   'bottled water',
#   'napkins',
#   'bottled beer',
#   'cleaner',
#   'other vegetables'],
#  ['rolls/buns',
#   'chocolate',
#   'sparkling wine',
#   'whole milk',
#   'dog food',
#   'soda',
#   'whipped/sour cream',
#   'whole milk',
#   'bottled water',
#   'pip fruit',
#   'pork',
#   'shopping bags',
#   'citrus fruit',
#   'turkey',
#   'canned beer',
#   'pip fruit',
#   'bottled water',
#   'whipped/sour cream',
#   'whole milk',
#   'chicken'],
#  ['soda',
#   'bottled water',
#   'brown bread',
#   'other vegetables',
#   'soda',
#   'whipped/sour cream',
#   'pasta',
#   'specialty chocolate',
#   'beverages',
#   'onions'],
#  ['margarine',
#   'rolls/buns',
#   'rolls/buns',
#   'rolls/buns',
#   'bottled beer',
#   'hard cheese',
#   'fruit/vegetable juice',
#   'newspapers',
#   'specialty bar'],
#  ['syrup',
#   'cling film/bags',
#   'pip fruit',
#   'baking powder',
#   'citrus fruit',
#   'soft cheese',
#   'rolls/buns',
#   'pickled vegetables',
#   'fruit/vegetable juice',
#   'root vegetables',
#   'whipped/sour cream'],
#  ['soda',
#   'hamburger meat',
#   'bottled water',
#   'berries',
#   'chocolate',
#   'brown bread',
#   'shopping bags',
#   'white wine',
#   'pasta',
#   'citrus fruit',
#   'butter',
#   'specialty chocolate',
#   'yogurt',
#   'other vegetables',
#   'oil',
#   'citrus fruit',
#   'beef',
#   'yogurt',
#   'whole milk'],
#  ['curd cheese',
#   'domestic eggs',
#   'pastry',
#   'soda',
#   'sugar',
#   'frozen potato products',
#   'other vegetables',
#   'bottled water',
#   'other vegetables',
#   'hard cheese',
#   'tropical fruit',
#   'whole milk',
#   'whole milk',
#   'tropical fruit'],
#  ['brown bread', 'rolls/buns', 'canned beer', 'dessert'],
#  ['shopping bags',
#   'coffee',
#   'tropical fruit',
#   'jam',
#   'chocolate',
#   'salt',
#   'bottled water',
#   'oil',
#   'ice cream',
#   'other vegetables',
#   'pork'],
#  ['cereals', 'soda', 'chicken', 'napkins', 'frozen meals'],
#  ['frozen potato products', 'white bread', 'citrus fruit', 'whole milk'],
#  ['white bread',
#   'root vegetables',
#   'mayonnaise',
#   'sausage',
#   'whole milk',
#   'dishes',
#   'oil',
#   'bottled beer'],
#  ['butter milk',
#   'whole milk',
#   'butter',
#   'shopping bags',
#   'beef',
#   'baking powder',
#   'pip fruit',
#   'rolls/buns',
#   'ice cream',
#   'mustard',
#   'canned fish',
#   'soft cheese',
#   'hamburger meat',
#   'hamburger meat',
#   'red/blush wine',
#   'candy'],
#  ['dessert',
#   'butter',
#   'bottled beer',
#   'brown bread',
#   'sausage',
#   'cream cheese',
#   'butter',
#   'domestic eggs',
#   'ham',
#   'canned beer',
#   'other vegetables',
#   'sausage',
#   'spread cheese',
#   'brown bread',
#   'root vegetables',
#   'pastry'],
#  ['root vegetables', 'newspapers', 'beef', 'whole milk', 'sweet spreads'],
#  ['pip fruit',
#   'ice cream',
#   'canned beer',
#   'chocolate',
#   'specialty bar',
#   'whole milk',
#   'frozen meals',
#   'beef',
#   'frankfurter',
#   'chewing gum'],
#  ['other vegetables',
#   'whole milk',
#   'detergent',
#   'soda',
#   'white bread',
#   'butter',
#   'soda',
#   'domestic eggs',
#   'canned fruit'],
#  ['other vegetables',
#   'soda',
#   'citrus fruit',
#   'soda',
#   'onions',
#   'shopping bags',
#   'domestic eggs'],
#  ['soda',
#   'butter milk',
#   'rolls/buns',
#   'bottled water',
#   'other vegetables',
#   'whole milk',
#   'cleaner',
#   'bottled beer'],
#  ['sliced cheese', 'dessert', 'bottled beer', 'tropical fruit'],
#  ['sparkling wine',
#   'root vegetables',
#   'root vegetables',
#   'hamburger meat',
#   'soda',
#   'rolls/buns',
#   'waffles',
#   'bottled beer',
#   'meat spreads',
#   'canned beer',
#   'soda',
#   'bottled water',
#   'other vegetables',
#   'whipped/sour cream',
#   'specialty chocolate',
#   'pip fruit',
#   'root vegetables'],
#  ['berries',
#   'hamburger meat',
#   'citrus fruit',
#   'white bread',
#   'other vegetables',
#   'specialty chocolate'],
#  ['fruit/vegetable juice',
#   'pastry',
#   'seasonal products',
#   'butter',
#   'brown bread'],
#  ['citrus fruit', 'soda', 'shopping bags', 'root vegetables'],
#  ['coffee',
#   'pastry',
#   'soda',
#   'bottled water',
#   'napkins',
#   'whole milk',
#   'honey',
#   'pip fruit',
#   'butter'],
#  ['shopping bags',
#   'finished products',
#   'liquor',
#   'butter',
#   'soft cheese',
#   'whole milk'],
#  ['shopping bags',
#   'bottled beer',
#   'domestic eggs',
#   'candy',
#   'pip fruit',
#   'mayonnaise',
#   'newspapers',
#   'rolls/buns'],
#  ['misc. beverages',
#   'whipped/sour cream',
#   'waffles',
#   'packaged fruit/vegetables',
#   'chocolate',
#   'beef',
#   'citrus fruit',
#   'yogurt',
#   'yogurt',
#   'root vegetables',
#   'whole milk',
#   'whipped/sour cream',
#   'pip fruit',
#   'sliced cheese',
#   'root vegetables',
#   'sausage',
#   'citrus fruit',
#   'brown bread'],
#  ['specialty chocolate',
#   'other vegetables',
#   'newspapers',
#   'specialty chocolate',
#   'frozen fish',
#   'napkins',
#   'citrus fruit'],
#  ['white bread',
#   'flour',
#   'bottled water',
#   'popcorn',
#   'salty snack',
#   'beverages',
#   'whole milk',
#   'rolls/buns',
#   'sugar',
#   'grapes',
#   'sausage',
#   'rolls/buns',
#   'canned vegetables'],
#  ['rolls/buns',
#   'root vegetables',
#   'brown bread',
#   'citrus fruit',
#   'canned fish',
#   'dessert',
#   'detergent',
#   'candy'],
#  ['candles', 'misc. beverages', 'coffee', 'whole milk'],
#  ['semi-finished bread',
#   'curd cheese',
#   'roll products',
#   'soda',
#   'yogurt',
#   'root vegetables',
#   'coffee',
#   'rolls/buns',
#   'oil',
#   'yogurt'],
#  ['bottled beer',
#   'rolls/buns',
#   'waffles',
#   'pastry',
#   'sliced cheese',
#   'root vegetables',
#   'chocolate',
#   'chicken',
#   'root vegetables',
#   'soda',
#   'softener',
#   'grapes',
#   'whole milk',
#   'yogurt',
#   'beverages',
#   'pip fruit'],
#  ['chewing gum',
#   'curd',
#   'whole milk',
#   'whole milk',
#   'ready soups',
#   'oil',
#   'yogurt',
#   'yogurt',
#   'white bread',
#   'bottled water'],
#  ['pastry',
#   'cat food',
#   'candles',
#   'soda',
#   'other vegetables',
#   'sausage',
#   'sugar',
#   'rolls/buns',
#   'soda',
#   'tropical fruit',
#   'whole milk',
#   'hygiene articles',
#   'sausage',
#   'softener'],
#  ['ham',
#   'pickled vegetables',
#   'semi-finished bread',
#   'yogurt',
#   'whole milk',
#   'shopping bags',
#   'frankfurter',
#   'whole milk'],
#  ['yogurt',
#   'butter milk',
#   'shopping bags',
#   'bottled water',
#   'soft cheese',
#   'beef',
#   'rolls/buns',
#   'frozen meals',
#   'tropical fruit',
#   'pork',
#   'misc. beverages'],
#  ['ham',
#   'fruit/vegetable juice',
#   'dessert',
#   'sausage',
#   'brown bread',
#   'shopping bags',
#   'specialty cheese',
#   'long life bakery product',
#   'yogurt'],
#  ['margarine',
#   'rolls/buns',
#   'tropical fruit',
#   'other vegetables',
#   'whole milk',
#   'yogurt',
#   'finished products',
#   'specialty bar',
#   'domestic eggs',
#   'butter',
#   'specialty bar',
#   'frankfurter',
#   'UHT-milk',
#   'specialty bar',
#   'butter',
#   'salty snack'],
#  ['root vegetables',
#   'tropical fruit',
#   'tropical fruit',
#   'other vegetables',
#   'domestic eggs',
#   'salt',
#   'beef',
#   'cat food'],
#  ['newspapers',
#   'citrus fruit',
#   'beef',
#   'domestic eggs',
#   'beef',
#   'margarine',
#   'fruit/vegetable juice',
#   'chicken',
#   'newspapers',
#   'dessert',
#   'brown bread',
#   'pork',
#   'bottled beer'],
#  ['yogurt', 'waffles', 'meat', 'chicken', 'syrup', 'pip fruit'],
#  ['shopping bags',
#   'sauces',
#   'semi-finished bread',
#   'yogurt',
#   'root vegetables',
#   'grapes',
#   'other vegetables',
#   'sliced cheese',
#   'pip fruit'],
#  ['root vegetables',
#   'canned beer',
#   'pastry',
#   'tropical fruit',
#   'bottled water',
#   'citrus fruit',
#   'specialty fat',
#   'brown bread',
#   'whole milk',
#   'onions',
#   'long life bakery product',
#   'turkey',
#   'napkins',
#   'soda'],
#  ['bottled water',
#   'pastry',
#   'grapes',
#   'whole milk',
#   'dog food',
#   'sugar',
#   'citrus fruit',
#   'whole milk'],
#  ['sausage',
#   'rolls/buns',
#   'curd',
#   'meat',
#   'meat',
#   'other vegetables',
#   'butter',
#   'citrus fruit',
#   'whole milk',
#   'cling film/bags',
#   'citrus fruit',
#   'pork',
#   'frozen meals',
#   'whole milk',
#   'tropical fruit',
#   'frozen fish',
#   'whole milk',
#   'tropical fruit',
#   'fruit/vegetable juice',
#   'candles',
#   'yogurt'],
#  ['red/blush wine', 'instant coffee', 'brown bread', 'canned beer'],
#  ['pastry',
#   'rolls/buns',
#   'dental care',
#   'rolls/buns',
#   'rice',
#   'chocolate',
#   'napkins',
#   'onions',
#   'canned beer',
#   'waffles',
#   'sausage',
#   'frankfurter',
#   'specialty chocolate',
#   'pasta',
#   'margarine',
#   'butter milk',
#   'ice cream'],
#  ['bottled water', 'sugar'],
#  ['onions', 'coffee', 'condensed milk', 'canned beer'],
#  ['rum',
#   'butter',
#   'semi-finished bread',
#   'citrus fruit',
#   'UHT-milk',
#   'citrus fruit',
#   'yogurt',
#   'flour',
#   'ham',
#   'packaged fruit/vegetables'],
#  ['cooking chocolate', 'sausage', 'UHT-milk', 'specialty chocolate'],
#  ['curd',
#   'jam',
#   'whole milk',
#   'pastry',
#   'photo/film',
#   'whole milk',
#   'shopping bags',
#   'butter milk',
#   'white bread',
#   'brown bread',
#   'seasonal products',
#   'whole milk',
#   'rolls/buns',
#   'soda',
#   'detergent',
#   'bottled beer',
#   'flour',
#   'dessert',
#   'whole milk',
#   'other vegetables',
#   'sliced cheese'],
#  ['specialty bar',
#   'pastry',
#   'long life bakery product',
#   'domestic eggs',
#   'white bread',
#   'beef',
#   'citrus fruit',
#   'soda',
#   'vinegar',
#   'hard cheese'],
#  ['whipped/sour cream', 'yogurt'],
#  ['beverages', 'photo/film', 'bottled beer'],
#  ['mustard',
#   'beef',
#   'white bread',
#   'whipped/sour cream',
#   'newspapers',
#   'brown bread',
#   'frozen potato products',
#   'ham'],
#  ['other vegetables',
#   'butter milk',
#   'soda',
#   'soda',
#   'sliced cheese',
#   'canned beer',
#   'frankfurter',
#   'misc. beverages',
#   'ham',
#   'canned beer',
#   'soda',
#   'domestic eggs',
#   'whole milk',
#   'pastry'],
#  ['onions',
#   'photo/film',
#   'margarine',
#   'pork',
#   'ice cream',
#   'sausage',
#   'root vegetables',
#   'detergent',
#   'grapes',
#   'hard cheese',
#   'soda',
#   'yogurt',
#   'sliced cheese',
#   'white wine',
#   'whipped/sour cream',
#   'flour'],
#  ['rolls/buns',
#   'bottled water',
#   'grapes',
#   'canned beer',
#   'pasta',
#   'butter',
#   'bottled beer'],
#  ['curd',
#   'margarine',
#   'canned beer',
#   'chicken',
#   'rolls/buns',
#   'other vegetables',
#   'whipped/sour cream',
#   'soda',
#   'whipped/sour cream',
#   'other vegetables',
#   'UHT-milk',
#   'soda',
#   'waffles',
#   'shopping bags',
#   'butter milk',
#   'whole milk',
#   'salty snack',
#   'rolls/buns',
#   'rolls/buns'],
#  ['shopping bags',
#   'margarine',
#   'coffee',
#   'curd',
#   'pastry',
#   'yogurt',
#   'salty snack',
#   'root vegetables',
#   'bottled water',
#   'root vegetables'],
#  ['condensed milk',
#   'shopping bags',
#   'dog food',
#   'abrasive cleaner',
#   'other vegetables',
#   'soda',
#   'sausage',
#   'processed cheese',
#   'canned beer',
#   'bottled beer',
#   'bottled water',
#   'sausage',
#   'curd',
#   'roll products',
#   'butter',
#   'other vegetables',
#   'waffles',
#   'bottled beer',
#   'spread cheese'],
#  ['newspapers', 'dishes', 'whole milk', 'cling film/bags', 'pip fruit'],
#  ['cream cheese',
#   'beverages',
#   'butter milk',
#   'other vegetables',
#   'other vegetables',
#   'sugar',
#   'whole milk',
#   'other vegetables',
#   'tropical fruit',
#   'pork',
#   'rolls/buns',
#   'hard cheese',
#   'misc. beverages',
#   'soda',
#   'ham',
#   'hard cheese',
#   'citrus fruit',
#   'white bread',
#   'cleaner',
#   'sugar'],
#  ['frankfurter', 'margarine'],
#  ['yogurt',
#   'soda',
#   'whole milk',
#   'yogurt',
#   'tropical fruit',
#   'finished products',
#   'waffles',
#   'brown bread',
#   'bottled water',
#   'roll products',
#   'whipped/sour cream',
#   'bottled beer',
#   'sausage',
#   'meat',
#   'processed cheese',
#   'condensed milk'],
#  ['whole milk',
#   'other vegetables',
#   'sausage',
#   'rolls/buns',
#   'shopping bags',
#   'hard cheese',
#   'soda',
#   'oil',
#   'frozen fish',
#   'onions',
#   'baking powder',
#   'frozen vegetables',
#   'frozen vegetables'],
#  ['soda',
#   'other vegetables',
#   'pasta',
#   'margarine',
#   'long life bakery product',
#   'meat',
#   'oil',
#   'whole milk',
#   'specialty cheese',
#   'specialty chocolate',
#   'pasta'],
#  ['sausage',
#   'chocolate',
#   'dog food',
#   'sausage',
#   'bottled water',
#   'other vegetables',
#   'citrus fruit',
#   'beverages',
#   'domestic eggs',
#   'bottled beer',
#   'beverages',
#   'sugar',
#   'tropical fruit',
#   'shopping bags',
#   'frozen meals',
#   'pasta',
#   'butter'],
#  ['soda', 'cling film/bags'],
#  ['soda',
#   'soft cheese',
#   'salty snack',
#   'bottled water',
#   'UHT-milk',
#   'shopping bags',
#   'candy',
#   'rolls/buns'],
#  ['soda',
#   'grapes',
#   'tropical fruit',
#   'other vegetables',
#   'soda',
#   'shopping bags',
#   'processed cheese',
#   'condensed milk',
#   'rolls/buns',
#   'white bread',
#   'dessert',
#   'rolls/buns',
#   'coffee',
#   'soft cheese',
#   'onions',
#   'canned fruit',
#   'shopping bags',
#   'turkey',
#   'soda',
#   'shopping bags'],
#  ['berries',
#   'whipped/sour cream',
#   'yogurt',
#   'canned beer',
#   'other vegetables',
#   'yogurt',
#   'tropical fruit',
#   'UHT-milk'],
#  ['frozen vegetables', 'candy', 'other vegetables', 'butter'],
#  ['beef',
#   'pip fruit',
#   'whole milk',
#   'margarine',
#   'frankfurter',
#   'curd',
#   'butter',
#   'chicken',
#   'packaged fruit/vegetables',
#   'frozen vegetables',
#   'dessert',
#   'margarine',
#   'skin care',
#   'root vegetables',
#   'tropical fruit',
#   'citrus fruit'],
#  ['citrus fruit', 'coffee', 'frozen meals', 'soda', 'bottled beer'],
#  ['chewing gum', 'other vegetables'],
#  ['fruit/vegetable juice', 'dessert', 'canned beer'],
#  ['chicken',
#   'other vegetables',
#   'turkey',
#   'soda',
#   'grapes',
#   'pork',
#   'pastry',
#   'whole milk',
#   'pot plants',
#   'dishes'],
#  ['liqueur',
#   'sausage',
#   'processed cheese',
#   'specialty cheese',
#   'baking powder',
#   'pastry'],
#  ['napkins', 'ham', 'specialty bar', 'specialty chocolate', 'white wine'],
#  ['soda', 'red/blush wine'],
#  ['tea',
#   'butter',
#   'coffee',
#   'oil',
#   'domestic eggs',
#   'sugar',
#   'UHT-milk',
#   'coffee',
#   'herbs',
#   'other vegetables',
#   'berries',
#   'sausage'],
#  ['cream cheese', 'yogurt', 'frozen dessert', 'rolls/buns'],
#  ['fruit/vegetable juice',
#   'whipped/sour cream',
#   'yogurt',
#   'rolls/buns',
#   'frozen vegetables',
#   'coffee'],
#  ['hamburger meat',
#   'coffee',
#   'sausage',
#   'root vegetables',
#   'whole milk',
#   'berries',
#   'grapes',
#   'shopping bags',
#   'sliced cheese',
#   'ice cream',
#   'whole milk',
#   'pork',
#   'napkins',
#   'fruit/vegetable juice'],
#  ['pip fruit', 'sausage', 'shopping bags', 'curd'],
#  ['rolls/buns',
#   'domestic eggs',
#   'rolls/buns',
#   'flower (seeds)',
#   'flour',
#   'canned vegetables',
#   'hard cheese',
#   'whole milk'],
#  ['frozen meals',
#   'whole milk',
#   'pickled vegetables',
#   'sugar',
#   'onions',
#   'organic sausage'],
#  ['bottled beer', 'citrus fruit', 'other vegetables', 'frozen meals'],
#  ['semi-finished bread',
#   'sausage',
#   'other vegetables',
#   'tropical fruit',
#   'mayonnaise',
#   'tropical fruit',
#   'yogurt',
#   'curd',
#   'tropical fruit',
#   'butter',
#   'white bread',
#   'bottled water',
#   'tropical fruit',
#   'sugar',
#   'soda',
#   'specialty bar',
#   'pastry'],
#  ['shopping bags',
#   'pork',
#   'waffles',
#   'cream cheese',
#   'other vegetables',
#   'soda',
#   'red/blush wine',
#   'curd',
#   'canned fish',
#   'UHT-milk',
#   'chicken',
#   'pastry',
#   'domestic eggs',
#   'tropical fruit',
#   'hamburger meat',
#   'specialty chocolate',
#   'yogurt',
#   'brown bread',
#   'root vegetables',
#   'pork',
#   'citrus fruit',
#   'other vegetables',
#   'pip fruit',
#   'whole milk',
#   'other vegetables'],
#  ['other vegetables', 'sliced cheese'],
#  ['whole milk', 'butter'],
#  ['sauces',
#   'oil',
#   'other vegetables',
#   'misc. beverages',
#   'white wine',
#   'whole milk',
#   'brown bread',
#   'canned fish',
#   'margarine'],
#  ['red/blush wine',
#   'frozen meals',
#   'liquor',
#   'canned fruit',
#   'butter milk',
#   'root vegetables',
#   'whole milk',
#   'softener',
#   'other vegetables',
#   'whole milk',
#   'seasonal products',
#   'rolls/buns',
#   'other vegetables',
#   'tropical fruit'],
#  ['cake bar',
#   'citrus fruit',
#   'pork',
#   'flower soil/fertilizer',
#   'cereals',
#   'napkins'],
#  ['cleaner', 'specialty bar'],
#  ['pork', 'whole milk', 'pastry', 'artif. sweetener'],
#  ['coffee',
#   'tidbits',
#   'rolls/buns',
#   'other vegetables',
#   'cream cheese',
#   'dessert',
#   'specialty cheese'],
#  ['citrus fruit',
#   'whole milk',
#   'domestic eggs',
#   'butter',
#   'rolls/buns',
#   'salt',
#   'onions',
#   'ice cream',
#   'curd',
#   'dessert',
#   'frozen potato products',
#   'mustard',
#   'sausage',
#   'shopping bags',
#   'butter',
#   'dental care',
#   'other vegetables',
#   'butter milk',
#   'specialty chocolate',
#   'white bread',
#   'root vegetables',
#   'citrus fruit',
#   'hygiene articles',
#   'pastry'],
#  ['rolls/buns',
#   'whole milk',
#   'hard cheese',
#   'hard cheese',
#   'bottled beer',
#   'whole milk',
#   'sausage',
#   'semi-finished bread',
#   'yogurt',
#   'cream cheese',
#   'dessert',
#   'condensed milk',
#   'house keeping products'],
#  ['pot plants',
#   'shopping bags',
#   'photo/film',
#   'whole milk',
#   'brown bread',
#   'other vegetables',
#   'whole milk',
#   'white bread',
#   'frankfurter',
#   'sausage',
#   'whipped/sour cream',
#   'dessert',
#   'yogurt',
#   'rolls/buns',
#   'butter'],
#  ['other vegetables',
#   'ice cream',
#   'frozen vegetables',
#   'photo/film',
#   'root vegetables',
#   'citrus fruit',
#   'canned beer',
#   'newspapers',
#   'bottled water',
#   'meat',
#   'butter',
#   'canned beer',
#   'root vegetables',
#   'hamburger meat',
#   'cookware'],
#  ['whole milk',
#   'citrus fruit',
#   'butter',
#   'ham',
#   'chicken',
#   'beverages',
#   'yogurt',
#   'rolls/buns',
#   'oil',
#   'tropical fruit',
#   'whole milk',
#   'sliced cheese',
#   'soda',
#   'sausage',
#   'pastry',
#   'sausage',
#   'root vegetables'],
#  ['fish',
#   'spices',
#   'butter milk',
#   'rolls/buns',
#   'finished products',
#   'spices',
#   'ice cream',
#   'UHT-milk'],
#  ['oil',
#   'coffee',
#   'rolls/buns',
#   'frozen vegetables',
#   'rolls/buns',
#   'hamburger meat',
#   'finished products',
#   'tropical fruit',
#   'newspapers'],
#  ['shopping bags',
#   'yogurt',
#   'misc. beverages',
#   'other vegetables',
#   'other vegetables',
#   'soda',
#   'snack products',
#   'white bread',
#   'shopping bags',
#   'bottled water'],
#  ['newspapers',
#   'bottled water',
#   'bottled water',
#   'frozen vegetables',
#   'chicken',
#   'pork',
#   'root vegetables',
#   'UHT-milk',
#   'specialty bar',
#   'cream cheese',
#   'bottled water',
#   'bottled water',
#   'onions',
#   'napkins',
#   'butter',
#   'whole milk',
#   'whipped/sour cream'],
#  ['margarine', 'salty snack', 'rolls/buns', 'soups'],
#  ['butter',
#   'rolls/buns',
#   'napkins',
#   'tropical fruit',
#   'hygiene articles',
#   'yogurt',
#   'butter',
#   'citrus fruit',
#   'shopping bags',
#   'chocolate marshmallow',
#   'soda',
#   'ice cream',
#   'pastry',
#   'bottled water'],
#  ['pork',
#   'yogurt',
#   'coffee',
#   'herbs',
#   'soda',
#   'bottled beer',
#   'domestic eggs',
#   'dessert',
#   'meat',
#   'pickled vegetables',
#   'whole milk',
#   'long life bakery product',
#   'hygiene articles',
#   'root vegetables',
#   'root vegetables',
#   'chewing gum'],
#  ['soft cheese',
#   'pip fruit',
#   'flower (seeds)',
#   'frankfurter',
#   'grapes',
#   'margarine',
#   'whipped/sour cream',
#   'whipped/sour cream',
#   'whole milk',
#   'ice cream',
#   'butter',
#   'other vegetables',
#   'pip fruit',
#   'citrus fruit',
#   'canned fruit',
#   'frozen meals',
#   'chicken'],
#  ['citrus fruit',
#   'abrasive cleaner',
#   'rolls/buns',
#   'napkins',
#   'whole milk',
#   'packaged fruit/vegetables',
#   'whole milk'],
#  ['herbs',
#   'canned beer',
#   'yogurt',
#   'prosecco',
#   'salty snack',
#   'napkins',
#   'root vegetables',
#   'brown bread',
#   'spread cheese',
#   'rolls/buns',
#   'other vegetables'],
#  ['margarine',
#   'cat food',
#   'margarine',
#   'whole milk',
#   'misc. beverages',
#   'other vegetables',
#   'rice',
#   'yogurt',
#   'sausage',
#   'frankfurter',
#   'frozen meals',
#   'sausage',
#   'whipped/sour cream'],
#  ['onions',
#   'sugar',
#   'citrus fruit',
#   'rolls/buns',
#   'domestic eggs',
#   'fruit/vegetable juice',
#   'tropical fruit',
#   'rolls/buns',
#   'domestic eggs',
#   'mustard',
#   'whole milk',
#   'rolls/buns'],
#  ['beverages', 'oil', 'whole milk', 'pork'],
#  ['specialty fat',
#   'light bulbs',
#   'whole milk',
#   'shopping bags',
#   'canned beer',
#   'pip fruit',
#   'dessert',
#   'hard cheese',
#   'whole milk',
#   'tropical fruit',
#   'specialty cheese'],
#  ['dishes',
#   'semi-finished bread',
#   'domestic eggs',
#   'soda',
#   'root vegetables',
#   'butter milk',
#   'white wine',
#   'waffles',
#   'soft cheese',
#   'other vegetables',
#   'whipped/sour cream',
#   'hygiene articles'],
#  ['frankfurter',
#   'bottled water',
#   'processed cheese',
#   'other vegetables',
#   'dessert',
#   'chicken',
#   'sausage',
#   'soda'],
#  ['meat',
#   'tropical fruit',
#   'yogurt',
#   'flower (seeds)',
#   'root vegetables',
#   'long life bakery product',
#   'other vegetables',
#   'hard cheese',
#   'soft cheese',
#   'rice',
#   'pickled vegetables',
#   'UHT-milk',
#   'bottled beer',
#   'pip fruit',
#   'beverages',
#   'root vegetables',
#   'jam'],
#  ['red/blush wine',
#   'cream cheese',
#   'yogurt',
#   'sausage',
#   'herbs',
#   'chicken',
#   'domestic eggs',
#   'house keeping products',
#   'napkins'],
#  ['soda',
#   'chicken',
#   'rolls/buns',
#   'dishes',
#   'bottled beer',
#   'pastry',
#   'Instant food products'],
#  ['bottled beer',
#   'rolls/buns',
#   'yogurt',
#   'canned beer',
#   'salty snack',
#   'whole milk',
#   'white bread',
#   'other vegetables'],
#  ['chicken', 'yogurt'],
#  ['soda',
#   'frozen vegetables',
#   'pip fruit',
#   'pot plants',
#   'sausage',
#   'whipped/sour cream',
#   'roll products'],
#  ['citrus fruit',
#   'root vegetables',
#   'yogurt',
#   'shopping bags',
#   'bottled water',
#   'hard cheese',
#   'root vegetables',
#   'rolls/buns',
#   'fruit/vegetable juice',
#   'butter'],
#  ['canned beer',
#   'whole milk',
#   'whole milk',
#   'canned fish',
#   'pastry',
#   'bottled beer',
#   'detergent',
#   'pastry',
#   'yogurt',
#   'rolls/buns',
#   'margarine',
#   'pasta',
#   'tropical fruit',
#   'pip fruit'],
#  ['other vegetables',
#   'whipped/sour cream',
#   'rolls/buns',
#   'hamburger meat',
#   'dishes',
#   'whole milk',
#   'frankfurter'],
#  ['white wine',
#   'flower (seeds)',
# ...
#  ['canned beer',
#   'bottled water',
#   'newspapers',
#   'citrus fruit',
#   'pastry',
#   'bottled beer',
#   'citrus fruit',
#   'napkins',
#   'photo/film'],
#  ['rolls/buns',
#   'chicken',
#   'other vegetables',
#   'pasta',
#   'finished products',
#   'other vegetables',
#   'soda',
#   'candy',
#   'newspapers',
#   'yogurt',
#   'yogurt',
#   'soda',
#   'rolls/buns',
#   'citrus fruit',
#   'berries',
#   'butter',
#   'butter',
#   'pastry',
#   'curd',
#   'bottled water',
#   'rolls/buns'],
#  ['tropical fruit',
#   'specialty bar',
#   'finished products',
#   'mayonnaise',
#   'soda',
#   'tropical fruit',
#   'UHT-milk',
#   'bottled water',
#   'soda',
#   'pork',
#   'candy',
#   'ham',
#   'fruit/vegetable juice'],
#  ['brown bread',
#   'soft cheese',
#   'beef',
#   'sliced cheese',
#   'salt',
#   'bottled water',
#   'bottled water',
#   'chicken',
#   'whole milk',
#   'pastry',
#   'chocolate',
#   'chocolate',
#   'pip fruit',
#   'other vegetables',
#   'other vegetables',
#   'oil'],
#  ['fruit/vegetable juice',
#   'chocolate',
#   'tropical fruit',
#   'citrus fruit',
#   'yogurt',
#   'whole milk',
#   'onions',
#   'pip fruit',
#   'oil',
#   'bottled water',
#   'zwieback',
#   'sausage',
#   'whole milk',
#   'cat food',
#   'UHT-milk',
#   'other vegetables',
#   'tropical fruit',
#   'bottled beer',
#   'specialty chocolate',
#   'chewing gum'],
#  ['white bread', 'tropical fruit'],
#  ['whipped/sour cream',
#   'napkins',
#   'tropical fruit',
#   'yogurt',
#   'curd',
#   'yogurt',
#   'fruit/vegetable juice',
#   'bottled beer',
#   'sugar',
#   'root vegetables',
#   'tropical fruit',
#   'sausage',
#   'pip fruit',
#   'rolls/buns',
#   'grapes',
#   'soda',
#   'grapes',
#   'beverages',
#   'other vegetables'],
#  ['whole milk',
#   'tropical fruit',
#   'mayonnaise',
#   'margarine',
#   'other vegetables',
#   'pip fruit',
#   'newspapers',
#   'yogurt',
#   'frozen vegetables',
#   'sweet spreads',
#   'processed cheese'],
#  ['meat spreads',
#   'newspapers',
#   'other vegetables',
#   'rolls/buns',
#   'berries',
#   'dishes'],
#  ['citrus fruit',
#   'whole milk',
#   'baking powder',
#   'whipped/sour cream',
#   'whole milk',
#   'popcorn',
#   'newspapers',
#   'canned beer',
#   'spread cheese',
#   'pip fruit',
#   'sugar',
#   'specialty bar',
#   'other vegetables'],
#  ['pastry',
#   'specialty bar',
#   'pork',
#   'rolls/buns',
#   'tropical fruit',
#   'butter',
#   'whole milk',
#   'bottled water',
#   'soda',
#   'tropical fruit'],
#  ['coffee',
#   'root vegetables',
#   'shopping bags',
#   'yogurt',
#   'frozen vegetables',
#   'long life bakery product',
#   'whole milk',
#   'tropical fruit',
#   'tropical fruit',
#   'sliced cheese',
#   'newspapers',
#   'rolls/buns',
#   'coffee',
#   'whipped/sour cream'],
#  ['chocolate',
#   'rolls/buns',
#   'beef',
#   'chewing gum',
#   'beef',
#   'chocolate',
#   'hygiene articles',
#   'whole milk',
#   'soft cheese',
#   'yogurt',
#   'domestic eggs'],
#  ['napkins', 'other vegetables', 'pot plants', 'whole milk', 'rolls/buns'],
#  ['frozen vegetables', 'onions', 'hamburger meat', 'pip fruit'],
#  ['canned beer',
#   'chicken',
#   'whole milk',
#   'onions',
#   'cocoa drinks',
#   'liquor',
#   'whole milk',
#   'bottled beer',
#   'canned fish',
#   'whole milk',
#   'potato products',
#   'tropical fruit',
#   'UHT-milk',
#   'other vegetables',
#   'frankfurter',
#   'bottled water',
#   'hamburger meat',
#   'UHT-milk',
#   'UHT-milk',
#   'canned fruit'],
#  ['whole milk', 'whipped/sour cream', 'pork', 'cake bar'],
#  ['curd',
#   'yogurt',
#   'fruit/vegetable juice',
#   'whole milk',
#   'whipped/sour cream',
#   'other vegetables',
#   'other vegetables',
#   'tropical fruit',
#   'hamburger meat',
#   'whipped/sour cream',
#   'bottled water',
#   'canned beer',
#   'oil',
#   'chocolate'],
#  ['onions',
#   'whipped/sour cream',
#   'whole milk',
#   'dessert',
#   'cream cheese',
#   'cooking chocolate',
#   'pastry',
#   'shopping bags',
#   'whole milk',
#   'candy',
#   'meat',
#   'shopping bags'],
#  ['whole milk',
#   'bottled beer',
#   'canned beer',
#   'margarine',
#   'specialty chocolate',
#   'whole milk',
#   'white bread',
#   'berries',
#   'other vegetables'],
#  ['yogurt',
#   'other vegetables',
#   'yogurt',
#   'baking powder',
#   'frozen vegetables',
#   'bottled water',
#   'soda',
#   'whole milk',
#   'pet care',
#   'dessert',
#   'margarine',
#   'frankfurter',
#   'other vegetables',
#   'pip fruit',
#   'whole milk',
#   'pastry',
#   'yogurt',
#   'whole milk',
#   'UHT-milk',
#   'herbs',
#   'hamburger meat',
#   'citrus fruit'],
#  ['whole milk',
#   'canned beer',
#   'soda',
#   'frozen vegetables',
#   'candy',
#   'salt',
#   'napkins',
#   'berries',
#   'semi-finished bread',
#   'napkins',
#   'soda',
#   'cat food',
#   'rolls/buns',
#   'ham',
#   'tropical fruit'],
#  ['other vegetables',
#   'dessert',
#   'other vegetables',
#   'sugar',
#   'whole milk',
#   'other vegetables',
#   'frozen vegetables',
#   'sausage',
#   'rolls/buns',
#   'sliced cheese'],
#  ['rolls/buns', 'herbs', 'bottled beer', 'frozen fish', 'curd', 'napkins'],
#  ['hygiene articles',
#   'tropical fruit',
#   'finished products',
#   'canned beer',
#   'pastry',
#   'pasta',
#   'onions',
#   'tropical fruit',
#   'pork',
#   'soda'],
#  ['citrus fruit', 'whole milk', 'pet care', 'beef'],
#  ['canned fish',
#   'coffee',
#   'onions',
#   'canned beer',
#   'pork',
#   'dishes',
#   'processed cheese',
#   'shopping bags',
#   'bottled beer',
#   'whole milk',
#   'hamburger meat'],
#  ['soda',
#   'napkins',
#   'cereals',
#   'rolls/buns',
#   'sausage',
#   'shopping bags',
#   'yogurt',
#   'rolls/buns'],
#  ['nut snack', 'butter'],
#  ['berries', 'root vegetables', 'root vegetables', 'processed cheese'],
#  ['liquor',
#   'artif. sweetener',
#   'other vegetables',
#   'cream cheese',
#   'hamburger meat',
#   'berries',
#   'whole milk'],
#  ['rolls/buns',
#   'specialty chocolate',
#   'soft cheese',
#   'fruit/vegetable juice',
#   'pip fruit',
#   'semi-finished bread',
#   'root vegetables',
#   'yogurt',
#   'pastry',
#   'root vegetables',
#   'pastry',
#   'citrus fruit',
#   'hamburger meat',
#   'bottled water',
#   'pot plants',
#   'other vegetables',
#   'tropical fruit',
#   'whole milk',
#   'softener'],
#  ['yogurt', 'chicken', 'rolls/buns', 'pastry'],
#  ['yogurt',
#   'rolls/buns',
#   'other vegetables',
#   'citrus fruit',
#   'frozen vegetables',
#   'tropical fruit',
#   'rolls/buns',
#   'dish cleaner',
#   'frozen vegetables',
#   'other vegetables',
#   'brown bread',
#   'sugar'],
#  ['soda',
#   'citrus fruit',
#   'frozen meals',
#   'pork',
#   'tropical fruit',
#   'hygiene articles',
#   'other vegetables',
#   'sausage',
#   'tropical fruit',
#   'rolls/buns'],
#  ['yogurt', 'citrus fruit'],
#  ['brown bread',
#   'hard cheese',
#   'pip fruit',
#   'domestic eggs',
#   'shopping bags',
#   'other vegetables',
#   'tropical fruit',
#   'hygiene articles',
#   'pickled vegetables',
#   'soda'],
#  ['yogurt', 'hamburger meat', 'chewing gum', 'other vegetables'],
#  ['specialty cheese',
#   'grapes',
#   'meat spreads',
#   'hard cheese',
#   'bottled water',
#   'frozen vegetables',
#   'cream cheese',
#   'rolls/buns',
#   'other vegetables',
#   'other vegetables',
#   'canned beer',
#   'white bread',
#   'vinegar',
#   'whole milk',
#   'white bread',
#   'yogurt'],
#  ['whole milk',
#   'hard cheese',
#   'frankfurter',
#   'soda',
#   'other vegetables',
#   'whole milk',
#   'fruit/vegetable juice',
#   'dental care',
#   'onions',
#   'grapes',
#   'waffles',
#   'seasonal products',
#   'other vegetables',
#   'brown bread',
#   'sausage'],
#  ['citrus fruit',
#   'whole milk',
#   'margarine',
#   'newspapers',
#   'hard cheese',
#   'whole milk',
#   'rolls/buns',
#   'zwieback',
#   'tropical fruit',
#   'frozen meals',
#   'pastry'],
#  ['bottled beer',
#   'waffles',
#   'other vegetables',
#   'cat food',
#   'frozen vegetables',
#   'sausage',
#   'citrus fruit',
#   'citrus fruit',
#   'pork',
#   'jam',
#   'fruit/vegetable juice',
#   'rolls/buns',
#   'other vegetables',
#   'other vegetables'],
#  ['white bread',
#   'whole milk',
#   'citrus fruit',
#   'ham',
#   'soda',
#   'curd',
#   'whipped/sour cream',
#   'brown bread',
#   'pastry'],
#  ['sausage',
#   'bottled water',
#   'sausage',
#   'frozen meals',
#   'dessert',
#   'curd',
#   'white wine',
#   'fruit/vegetable juice'],
#  ['bottled beer',
#   'whipped/sour cream',
#   'pork',
#   'pasta',
#   'fruit/vegetable juice'],
#  ['specialty chocolate', 'beef'],
#  ['brown bread',
#   'packaged fruit/vegetables',
#   'specialty chocolate',
#   'fish',
#   'frozen meals'],
#  ['root vegetables', 'yogurt', 'soups', 'rolls/buns'],
#  ['root vegetables', 'bottled water', 'other vegetables'],
#  ['whole milk', 'beef', 'canned beer'],
#  ['cookware', 'beef', 'brown bread', 'yogurt', 'yogurt', 'turkey'],
#  ['yogurt',
#   'beef',
#   'bottled water',
#   'root vegetables',
#   'brown bread',
#   'herbs',
#   'detergent',
#   'whole milk',
#   'brown bread',
#   'whole milk',
#   'white bread',
#   'butter milk',
#   'frozen vegetables',
#   'frozen meals',
#   'pastry',
#   'pork',
#   'salty snack'],
#  ['bottled water',
#   'frozen vegetables',
#   'berries',
#   'chocolate marshmallow',
#   'salty snack',
#   'flour',
#   'white bread',
#   'domestic eggs',
#   'brown bread',
#   'citrus fruit'],
#  ['whole milk', 'specialty chocolate', 'fruit/vegetable juice', 'chicken'],
#  ['coffee',
#   'liqueur',
#   'tropical fruit',
#   'frozen fruits',
#   'chocolate',
#   'butter',
#   'butter'],
#  ['margarine',
#   'rolls/buns',
#   'whole milk',
#   'whole milk',
#   'sausage',
#   'soda',
#   'white wine',
#   'pastry',
#   'hamburger meat',
#   'pip fruit',
#   'ice cream',
#   'processed cheese',
#   'berries',
#   'bathroom cleaner',
#   'hamburger meat',
#   'whole milk'],
#  ['whole milk',
#   'sausage',
#   'bottled water',
#   'butter milk',
#   'rolls/buns',
#   'dessert',
#   'whole milk',
#   'bottled water'],
#  ['rolls/buns',
#   'fruit/vegetable juice',
#   'citrus fruit',
#   'long life bakery product',
#   'pork',
#   'chocolate',
#   'yogurt',
#   'domestic eggs',
#   'napkins'],
#  ['other vegetables',
#   'bottled beer',
#   'curd',
#   'grapes',
#   'whipped/sour cream',
#   'bottled water'],
#  ['soda', 'mustard'],
#  ['rolls/buns',
#   'tropical fruit',
#   'whole milk',
#   'yogurt',
#   'flower (seeds)',
#   'citrus fruit'],
#  ['long life bakery product',
#   'butter',
#   'fruit/vegetable juice',
#   'flour',
#   'specialty bar',
#   'citrus fruit',
#   'white wine',
#   'frozen fish',
#   'soda',
#   'newspapers',
#   'soap',
#   'soda',
#   'sausage',
#   'other vegetables',
#   'pork',
#   'fruit/vegetable juice',
#   'tropical fruit',
#   'chicken',
#   'coffee',
#   'butter',
#   'bottled beer',
#   'nuts/prunes',
#   'yogurt'],
#  ['pastry',
#   'seasonal products',
#   'beef',
#   'rolls/buns',
#   'beef',
#   'white bread',
#   'other vegetables',
#   'rolls/buns'],
#  ['pip fruit',
#   'rolls/buns',
#   'tropical fruit',
#   'chicken',
#   'root vegetables',
#   'waffles',
#   'pet care',
#   'curd',
#   'root vegetables'],
#  ['whole milk',
#   'whole milk',
#   'whole milk',
#   'coffee',
#   'bottled beer',
#   'chocolate',
#   'yogurt',
#   'soda',
#   'waffles',
#   'pip fruit',
#   'canned beer',
#   'bottled beer',
#   'fruit/vegetable juice',
#   'whole milk'],
#  ['brown bread',
#   'margarine',
#   'root vegetables',
#   'shopping bags',
#   'root vegetables',
#   'root vegetables',
#   'white bread',
#   'soda',
#   'frozen meals',
#   'rolls/buns',
#   'other vegetables',
#   'soft cheese',
#   'yogurt',
#   'other vegetables',
#   'fruit/vegetable juice',
#   'pet care',
#   'frozen dessert'],
#  ['canned beer',
#   'whipped/sour cream',
#   'soda',
#   'root vegetables',
#   'flower (seeds)',
#   'rolls/buns',
#   'domestic eggs',
#   'yogurt',
#   'rolls/buns',
#   'roll products'],
#  ['canned beer',
#   'brown bread',
#   'soda',
#   'soda',
#   'beverages',
#   'berries',
#   'pip fruit',
#   'pastry',
#   'bottled beer',
#   'white bread',
#   'cleaner',
#   'bottled water',
#   'frankfurter',
#   'shopping bags',
#   'newspapers',
#   'citrus fruit',
#   'ham',
#   'processed cheese',
#   'pip fruit',
#   'pickled vegetables',
#   'frankfurter'],
#  ['misc. beverages',
#   'pip fruit',
#   'frankfurter',
#   'chewing gum',
#   'pork',
#   'canned vegetables',
#   'ice cream',
#   'root vegetables',
#   'sauces',
#   'citrus fruit',
#   'frankfurter',
#   'frozen vegetables',
#   'whole milk',
#   'rolls/buns',
#   'whipped/sour cream',
#   'candles',
#   'pot plants',
#   'pastry',
#   'canned beer',
#   'citrus fruit',
#   'chewing gum',
#   'whipped/sour cream',
#   'dishes',
#   'waffles',
#   'whole milk',
#   'root vegetables',
#   'whipped/sour cream'],
#  ['hygiene articles',
#   'shopping bags',
#   'frozen vegetables',
#   'coffee',
#   'brown bread',
#   'tropical fruit',
#   'rolls/buns',
#   'cream cheese',
#   'tropical fruit',
#   'white wine',
#   'dog food',
#   'soft cheese',
#   'ice cream',
#   'misc. beverages',
#   'butter',
#   'popcorn'],
#  ['fruit/vegetable juice',
#   'dish cleaner',
#   'sparkling wine',
#   'bottled beer',
#   'bottled beer',
#   'hamburger meat',
#   'rolls/buns'],
#  ['rolls/buns',
#   'shopping bags',
#   'root vegetables',
#   'beef',
#   'other vegetables',
#   'citrus fruit',
#   'yogurt',
#   'bottled water',
#   'beef',
#   'citrus fruit',
#   'butter milk',
#   'spices',
#   'chocolate',
#   'whole milk',
#   'butter',
#   'other vegetables',
#   'cereals',
#   'napkins',
#   'other vegetables',
#   'processed cheese'],
#  ['root vegetables',
#   'pork',
#   'beverages',
#   'onions',
#   'frozen vegetables',
#   'rolls/buns',
#   'meat'],
#  ['baking powder',
#   'brown bread',
#   'sausage',
#   'frozen dessert',
#   'other vegetables',
#   'liquor'],
#  ['pastry',
#   'other vegetables',
#   'grapes',
#   'tropical fruit',
#   'yogurt',
#   'butter',
#   'beef',
#   'cream cheese',
#   'mustard',
#   'other vegetables',
#   'beverages',
#   'hamburger meat',
#   'pip fruit'],
#  ['brown bread',
#   'male cosmetics',
#   'yogurt',
#   'jam',
#   'yogurt',
#   'mustard',
#   'dessert',
#   'soda',
#   'cat food',
#   'bottled beer',
#   'pork',
#   'bottled beer',
#   'rolls/buns'],
#  ['coffee', 'frozen potato products', 'frankfurter', 'pot plants'],
#  ['brown bread',
#   'dessert',
#   'cream cheese',
#   'whole milk',
#   'photo/film',
#   'whole milk'],
#  ['soda',
#   'soda',
#   'root vegetables',
#   'mayonnaise',
#   'whole milk',
#   'domestic eggs'],
#  ['pastry', 'prosecco', 'tropical fruit', 'pork', 'soda', 'rolls/buns'],
#  ['yogurt',
#   'root vegetables',
#   'soda',
#   'specialty bar',
#   'soda',
#   'waffles',
#   'other vegetables',
#   'bottled water',
#   'shopping bags',
#   'yogurt',
#   'whole milk',
#   'soda'],
#  ['candles',
#   'beverages',
#   'yogurt',
#   'onions',
#   'frankfurter',
#   'pip fruit',
#   'liquor',
#   'UHT-milk',
#   'rolls/buns',
#   'soda',
#   'mayonnaise',
#   'other vegetables',
#   'soda',
#   'shopping bags',
#   'whipped/sour cream',
#   'yogurt',
#   'fruit/vegetable juice',
#   'soda'],
#  ['rolls/buns', 'butter milk', 'bottled water', 'cling film/bags'],
#  ['onions',
#   'rolls/buns',
#   'other vegetables',
#   'packaged fruit/vegetables',
#   'yogurt',
#   'domestic eggs',
#   'UHT-milk'],
#  ['white bread',
#   'pip fruit',
#   'yogurt',
#   'yogurt',
#   'cake bar',
#   'dessert',
#   'brown bread',
#   'bottled water',
#   'dessert',
#   'yogurt',
#   'whole milk',
#   'frozen vegetables',
#   'yogurt',
#   'coffee',
#   'ice cream',
#   'oil',
#   'syrup',
#   'other vegetables',
#   'soft cheese'],
#  ['rum', 'tropical fruit', 'pork', 'soda'],
#  ['sugar', 'berries', 'whipped/sour cream', 'pip fruit'],
#  ['root vegetables',
#   'waffles',
#   'bottled beer',
#   'whole milk',
#   'bottled water',
#   'coffee',
#   'chocolate',
#   'white wine',
#   'dog food',
#   'seasonal products',
#   'UHT-milk',
#   'pip fruit',
#   'tropical fruit',
#   'chicken',
#   'nuts/prunes',
#   'whipped/sour cream'],
#  ['rolls/buns',
#   'curd',
#   'tropical fruit',
#   'frozen meals',
#   'soda',
#   'coffee',
#   'bottled beer',
#   'waffles',
#   'chicken',
#   'frozen potato products',
#   'rolls/buns',
#   'chocolate',
#   'canned beer'],
#  ['candles',
#   'brown bread',
#   'candy',
#   'salty snack',
#   'sausage',
#   'other vegetables',
#   'other vegetables',
#   'white bread',
#   'frankfurter',
#   'fruit/vegetable juice',
#   'flour',
#   'citrus fruit',
#   'frozen meals',
#   'sausage',
#   'citrus fruit',
#   'waffles',
#   'tropical fruit',
#   'whipped/sour cream'],
#  ['rolls/buns',
#   'fruit/vegetable juice',
#   'hamburger meat',
#   'hygiene articles',
#   'sliced cheese',
#   'pastry',
#   'yogurt',
#   'beef',
#   'sausage'],
#  ['whole milk', 'meat'],
#  ['candy',
#   'hard cheese',
#   'soft cheese',
#   'sausage',
#   'herbs',
#   'rolls/buns',
#   'other vegetables',
#   'cat food',
#   'whole milk',
#   'UHT-milk',
#   'white wine',
#   'yogurt',
#   'frankfurter',
#   'hard cheese',
#   'long life bakery product',
#   'curd cheese',
#   'newspapers',
#   'beef',
#   'fruit/vegetable juice',
#   'rolls/buns',
#   'sugar',
#   'other vegetables',
#   'pork'],
#  ['spread cheese',
#   'tropical fruit',
#   'bottled beer',
#   'citrus fruit',
#   'hard cheese',
#   'other vegetables',
#   'roll products'],
#  ['canned beer', 'margarine', 'dessert', 'yogurt'],
#  ...]

# %% [markdown]
# # Importing and Setting the apriori options
# * 1. Minimum Support
# * 2. Minimum Confidence
# * 3. Minimum Lift
# * 4. Length = the number of items

# %%
#Importing and Setting the apriori options
#1. Minimum Support
#2. Minimum Confidence
#3. Minimum Lift
#4. Lenght = the number of items

# %%
from apyori import apriori ## Importing apriori package
rules = apriori(transactions = trx, min_support = 0.002, min_confidence = 0.05, min_lift = 3, min_length = 2, max_length = 2) ## Model Creation

# %%
results = list(rules)

# %%
## Creating user-defined function for arranging the results obtained from model into readable format

def inspect(results):
    x         = [tuple(result[2][0][0])[0] for result in results]
    y         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(x, y, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['X', 'Y', 'Support', 'Confidence', 'Lift'])

# %%
resultsinDataFrame.nlargest(n=10, columns="Lift") ## Showing best possible scenarios
# Out:
#                  X              Y   Support  Confidence      Lift
# 0   kitchen towels       UHT-milk  0.002309    0.300000  3.821569
# 1  potato products           beef  0.002565    0.454545  3.802185
# 2     canned fruit         coffee  0.002309    0.428571  3.728954
# 4            flour     mayonnaise  0.002309    0.063380  3.338599
# 6   sparkling wine        waffles  0.002565    0.217391  3.150154
# 5             rice        napkins  0.003079    0.244898  3.011395
# 3     meat spreads  domestic eggs  0.003592    0.400000  3.004239
